# %%
import os
from pathlib import Path

import ee
import geemap
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import pandas as pd
import seaborn as sns
from psmpy import PsmPy
from scipy.stats import ks_2samp, ttest_ind

from belo_horizonte.bounds import load_bounds
from belo_horizonte.canopy import get_canopy_area
from belo_horizonte.sample import generate_full_samples
from belo_horizonte.temperature import get_lst

# %%
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
GREEN = "#2E8B57"
BROWN = "#A0522D"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
data_path = Path(os.environ["DATA_PATH"])

figure_path = data_path / "figures"
figure_path.mkdir(parents=True, exist_ok=True)

results_path = data_path / "results"
results_path.mkdir(parents=True, exist_ok=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Bounds

# %%
bounds_ee = load_bounds(data_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Canopy

# %%
img_canopy = (
    ee.ImageCollection("projects/sat-io/open-datasets/facebook/meta-canopy-height")
    .filterBounds(bounds_ee)
    .first()
)

canopy_mask = (
    ee.image.Image("projects/ee-ursa-test/assets/belo_horizonte/height_3")
    .divide(900)
    .clamp(0, 1)
    .gte(0.3)
    .rename(["type"])
    .selfMask()
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
img_date = ee.Image("projects/wri-datalab/CanopyHeightDate")
img_date.reduceRegion(ee.reducer.Reducer.frequencyHistogram(), bounds_ee, 30).getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'b1': {'18.75': 7261.00392156863,
#   '19.41666603088379': 109576.31372549031,
#   '19.5': 84644.30588235291,
#   '19.58333396911621': 188.61960784313726,
#   '19.75': 100726.3686274512,
#   '19.83333396911621': 33500.039215686345}}

# %% [markdown]
# # Temperature

# %%
lst = get_lst(
    col_name="LANDSAT/LC08/C02/T1_L2",
    year=2020,
    temp_band="ST_B10",
    qa_band="QA_PIXEL",
    bounds=bounds_ee,
)

m = geemap.Map(center=[-19.9207, -43.9378], zoom=12)
m.addLayer(canopy_mask.clip(bounds_ee))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-19.9207, -43.9378], controls=(WidgetControl(options=['position', 'transparent_bg'], position='top…

# %% [markdown]
# # Regions

# %%
df_regions = gpd.read_file(
    data_path
    / "Areas de intervencion"
    / "140 areas degradadas"
    / "AREAS_PLANTIO"
    / "shapefiles"
    / "PL_limite_areas_BH_VERDE_AZUL.shp",
).filter(["ID_DESTINA", "geometry"])

df_regions_heights = get_canopy_area(
    img_canopy,
    geemap.geopandas_to_ee(df_regions.to_crs("EPSG:4326")),
    index_col="ID_DESTINA",
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df_full_regions = gpd.read_file(
    data_path
    / "Areas de intervencion"
    / "140 areas degradadas"
    / "AREAS_PLANTIO"
    / "shapefiles"
    / "PL_limite_area_verde_publica.shp",
).assign(fid=lambda df: df["fid"].astype(int))

df_full_regions_heights = get_canopy_area(
    img_canopy,
    geemap.geopandas_to_ee(df_full_regions.to_crs("EPSG:4326")),
    index_col="fid",
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Histogram

# %%
h1 = (
    df_regions_heights.drop(columns=[0, 1, 2])
    .sum(axis=1)
    .divide(df_regions_heights.sum(axis=1))
)
h2 = (
    df_full_regions_heights.drop(columns=[0, 1, 2])
    .sum(axis=1)
    .divide(df_full_regions_heights.sum(axis=1))
)
heights = pd.concat(
    [
        h1.rename("area_frac").to_frame().assign(Tipo="Degradada"),
        h2.rename("area_frac").to_frame().assign(Tipo="Área verde"),
    ],
    ignore_index=True,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sns.set_theme(style="ticks", font_scale=1.5)

fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(
    heights,
    x="area_frac",
    hue="Tipo",
    common_norm=False,
    stat="percent",
    fill=True,
    multiple="layer",
    ax=ax,
    palette=[BROWN, GREEN],
)
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(100))
ax.set_xlabel("Porcentaje de cobertura arbórea")
ax.set_ylabel("Porcentaje del total de áreas")
fig.savefig(
    figure_path / "canopy_coverage_histogram.jpg",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Heat

# %%
col_regions = geemap.geopandas_to_ee(df_regions.to_crs("EPSG:4326"))
temp_regions = ee.data.computeFeatures(
    {
        "expression": lst.reduceRegions(
            collection=col_regions,
            reducer=ee.Reducer.mean(),
            scale=30,
        ),
        "fileFormat": "GEOPANDAS_GEODATAFRAME",
    },
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
col_regions_full = geemap.geopandas_to_ee(df_full_regions.to_crs("EPSG:4326"))
temp_regions_full = ee.data.computeFeatures(
    {
        "expression": lst.reduceRegions(
            collection=col_regions_full,
            reducer=ee.Reducer.mean(),
            scale=30,
        ),
        "fileFormat": "GEOPANDAS_GEODATAFRAME",
    },
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sns.set_theme(style="ticks", font_scale=1.5)

fig, ax = plt.subplots(figsize=(10, 4))
sns.boxplot(
    pd.concat(
        [
            temp_regions[["mean"]].assign(Tipo="Degradada"),
            temp_regions_full[["mean"]].assign(Tipo="Área verde"),
        ],
        ignore_index=True,
    ),
    x="mean",
    y="Tipo",
    ax=ax,
    hue="Tipo",
    palette=[BROWN, GREEN],
)
# centigrados
ax.set_xlabel("Temperatura superficial (°C)")
ax.set_ylabel("")
fig.savefig(
    figure_path / "lst_boxplot.jpg", dpi=300, bbox_inches="tight", transparent=True,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Points

# %%
# df_samples_control = generate_full_samples(df_regions.set_index("ID_DESTINA").assign(geometry=lambda df: df["geometry"].centroid)["geometry"], data_path=data_path, bounds=bounds_ee)
points_control = (
    df_regions.sample_points(2, seed=42)
    .explode()
    .reset_index(drop=True)
    .rename("geometry")
)
df_samples_control = generate_full_samples(
    points_control,
    data_path=data_path,
    bounds=bounds_ee,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
points_treatment = (
    (
        ee.data.computeFeatures(
            {
                "expression": ee.image.Image.constant(1)
                .addBands(canopy_mask)
                .stratifiedSample(
                    numPoints=2000,
                    classBand="type",
                    region=bounds_ee,
                    scale=30,
                    geometries=True,
                    seed=42,
                ),
                "fileFormat": "GEOPANDAS_GEODATAFRAME",
            },
        )
        .drop(columns=["constant", "type"])
        .reset_index(names="index")
    )
    .set_crs("EPSG:4326")
    .to_crs(df_regions.crs)["geometry"]
)

df_samples_treatment = generate_full_samples(
    points_treatment,
    data_path=data_path,
    bounds=bounds_ee,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df_samples = pd.concat(
    [df_samples_control.assign(type=0), df_samples_treatment.assign(type=1)],
    ignore_index=True,
)

temp = df_samples.filter(like="landuse").isna().all(axis=1)
unwanted_idx = temp[temp].index

df_samples = df_samples.drop(index=unwanted_idx).reset_index(drop=True)

col_samples = geemap.geopandas_to_ee(
    df_samples[["geometry"]].reset_index(names="index").to_crs("EPSG:4326"),
)

temperature = ee.data.computeFeatures(
    {
        "expression": lst.sampleRegions(
            collection=col_samples,
            scale=30,
            geometries=False,
        ),
        "fileFormat": "GEOPANDAS_GEODATAFRAME",
    },
).set_index("index")["b2020"]

df_samples = df_samples.assign(temp=temperature)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df_samples.drop(columns=["geometry"]).to_csv("./df.csv")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Matching

# %%
not_matched = df_samples.reset_index(names="index").drop(columns=["geometry"])

psm = PsmPy(not_matched, treatment="type", indx="index", seed=42, exclude=["temp"])
psm.logistic_ps(balance=True)

psm.kdtree_matched(
    matcher="propensity_logit",
    replacement=False,
    caliper=0.05,
    drop_unmatched=True,
)

# psm.kdtree_matched_12n(matcher="propensity_logit", how_many=2)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sns.set_theme(style="ticks")

fig, (axl, axr) = plt.subplots(1, 2, figsize=(12, 5))
sns.kdeplot(
    psm.predicted_data,
    hue="type",
    x="propensity_score",
    ax=axl,
    common_norm=False,
    shade=True,
)
sns.kdeplot(
    psm.predicted_data,
    hue="type",
    x="propensity_logit",
    ax=axr,
    common_norm=False,
    shade=True,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Axes: xlabel='propensity_logit', ylabel='Density'>

# %%
matched_treatment = df_samples.loc[psm.matched_ids["matched_ID"]]
matched_control = df_samples.loc[psm.matched_ids["index"]]
matched = pd.concat([matched_treatment, matched_control])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
len(matched) / 2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 234.0

# %%
sns.set_theme(style="ticks")

wanted_cols = df_samples.columns.drop(
    ["type", "geometry", "start_temp", "end_temp"],
    errors="ignore",
)

fig = plt.figure(figsize=(10, 2 * len(wanted_cols)), constrained_layout=True)
subfigs = fig.subfigures(len(wanted_cols), 1)

for var, subfig in zip(wanted_cols, subfigs):
    axl, axr = subfig.subplots(1, 2)
    sns.kdeplot(
        data=not_matched, x=var, hue="type", ax=axl, common_norm=False, legend=False,
    )
    sns.kdeplot(
        data=matched, x=var, hue="type", ax=axr, common_norm=False, legend=False,
    )

    # sns.histplot(data=not_matched, x=var, hue="type", ax=axl, common_norm=False, stat="density", legend=False)
    # sns.histplot(data=matched, x=var, hue="type", ax=axr, common_norm=False, stat="density", legend=False)

    axl.set_title("Before Matching")
    axr.set_title("After Matching")
    axl.set_xlabel("")
    axr.set_xlabel("")
    subfig.suptitle(var)

fig.savefig(
    figure_path / "psm_matching.jpg", dpi=300, bbox_inches="tight", transparent=True,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sns.set_theme(style="ticks", font_scale=1.5)
fig, ax = plt.subplots(figsize=(10, 4))
sns.boxplot(
    matched.assign(type=lambda df: df["type"].map({0: "Control", 1: "Tratamiento"})),
    x="temp",
    y="type",
    hue="type",
    palette=[GREEN, BROWN],
    ax=ax,
)
ax.set_xlabel("Temperatura superficial (°C)")
ax.set_ylabel("")
fig.savefig(
    figure_path / "lst_matched_boxplot.jpg",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sns.kdeplot(
    matched, x="temp", hue="type", common_norm=False, fill=True, palette=[BROWN, GREEN],
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Axes: xlabel='temp', ylabel='Density'>

# %%
diffs = matched.groupby("type")["temp"].mean()
display(diffs)
diffs[0] - diffs[1]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# type
# 0    35.151205
# 1    34.139563
# Name: temp, dtype: float64
# np.float64(1.0116423539003065)

# %%
matched
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                             geometry  elevation  slope     lights  \
# 1071   POINT (609012.226 7811339.99)      800.0      1  14.025764
# 292   POINT (608876.382 7812205.794)      815.0      4  14.608675
# 426   POINT (609160.727 7812532.137)      820.0      4  14.608675
# 833   POINT (603573.808 7803468.674)      845.0      1  14.752389
# 1465  POINT (608754.484 7810745.044)      885.0      4  22.300472
# ...                              ...        ...    ...        ...
# 272   POINT (602384.356 7795953.379)      925.0      3  39.219913
# 273   POINT (611254.765 7802519.527)      825.0      2  43.007114
# 274   POINT (611268.875 7802529.472)      825.0      2  43.007114
# 275   POINT (611283.565 7802543.459)      825.0      5  43.007114
# 276   POINT (611295.718 7802550.898)      825.0      2  43.007114
#
#       landuse_vacant_lot  landuse_mixed_use  landuse_non_residential  \
# 1071            0.000000                0.0                 0.000000
# 292             0.000000                0.0                 0.000000
# 426             0.000000                0.0                 0.000000
# 833             0.000000                0.0                 0.000000
# 1465            0.000000                0.0                 0.000000
# ...                  ...                ...                      ...
# 272             1.000000                0.0                 0.000000
# 273             0.998425                0.0                 0.001575
# 274             0.974518                0.0                 0.025482
# 275             0.885942                0.0                 0.114058
# 276             0.818924                0.0                 0.181076
#
#       landuse_park  landuse_residential  type       temp
# 1071           1.0                  0.0     1  29.447843
# 292            1.0                  0.0     1  33.724926
# 426            1.0                  0.0     1  32.983215
# 833            1.0                  0.0     1  31.889449
# 1465           1.0                  0.0     1  34.967376
# ...            ...                  ...   ...        ...
# 272            0.0                  0.0     0  34.842618
# 273            0.0                  0.0     0  38.798976
# 274            0.0                  0.0     0  37.481330
# 275            0.0                  0.0     0  39.470617
# 276            0.0                  0.0     0  38.556297
#
# [468 rows x 11 columns]

# %%
temp = matched.dropna(subset=["temp"])
temp_control = temp.loc[temp["type"] == 0, "temp"].to_numpy()
temp_treatment = temp.loc[temp["type"] == 1, "temp"].to_numpy()

ks_2samp(
    temp_control,
    temp_treatment,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# KstestResult(statistic=np.float64(0.27663572060123787), pvalue=np.float64(2.1882306092848382e-08), statistic_location=np.float64(33.342107540000015), statistic_sign=np.int8(-1))

# %%
(1 - 2.1882306092848382e-08) * 100
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 99.99999781176939

# %%
ttest_ind(temp_control, temp_treatment)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# TtestResult(statistic=np.float64(4.643397499075202), pvalue=np.float64(4.468521033012323e-06), df=np.float64(464.0))

# %% [markdown]
# # Save

# %%
matched.reset_index(drop=True).to_file(results_path / "matched_points.gpkg")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
geemap.download_ee_image(
    lst, results_path / "temperature.tif", bounds_ee, crs="EPSG:32623", scale=30,
)
geemap.download_ee_image(
    canopy_mask, results_path / "green_zones.tif", bounds_ee, crs="EPSG:32623", scale=30,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   0%|          |0/2 tiles [00:00<?]
#   0%|          |0/1 tiles [00:00<?]
